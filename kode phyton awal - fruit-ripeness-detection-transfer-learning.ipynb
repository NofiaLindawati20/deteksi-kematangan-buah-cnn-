# %% [markdown]
# ---
#  # **Automated Ripeness Detection of Fruits using Deep Learning**
# ---

# %% [markdown]
# ## 1. Importing Necessary Modules and Libraries

# %%
import os

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import InceptionV3, VGG19, Xception
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## 2. Class Definitions

# %% [markdown]
# ### 2.1 Configuration

# %%
class Configuration:
    def __init__(self):
        self.data_dir = 'C:/Users/nofia/pcd/Deteksi buah/dataset_buah'
        self.output_dir = 'C:/Users/nofia/pcd/Deteksi buah/output'
        self.image_size = (224,224)
        self.batch_size = 32
        self.num_classes = 3
        self.optimizer = Adam
        self.learning_rate = 0.001
        self.epochs = 20
        self.loss = CategoricalCrossentropy()
        self.metrics = ['categorical_accuracy', 'precision', 'recall', 'auc']

# %%
# PATH DATASET (LOCAL WINDOWS)
base = "dataset_buah"   # <- INI KUNCI UTAMA

if not os.path.exists(base):
    raise FileNotFoundError("Folder dataset tidak ditemukan: " + os.path.abspath(base))

print("Lokasi dataset:", os.path.abspath(base))
print("Isi dataset:", os.listdir(base))

IMG_SIZE = (224, 224)
BATCH_SIZE = 16

datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

train_gen = datagen.flow_from_directory(
    base,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training",
    shuffle=True
)

val_gen = datagen.flow_from_directory(
    base,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation",
    shuffle=False
)

print("Kelas terdeteksi:", train_gen.class_indices)
# Out:
# Lokasi dataset: C:\Users\nofia\pcd\Deteksi buah\dataset_buah
# Isi dataset: ['Test', 'Train']
# Found 3692 images belonging to 2 classes.
# Found 922 images belonging to 2 classes.
# Kelas terdeteksi: {'Test': 0, 'Train': 1}

# %% [markdown]
# ### 2.2 DataLoader

# %%
class DataLoader:
    def __init__(self, data_dir, validation_split=0.1):
        self.train_dir = os.path.join(data_dir, 'Train')
        self.test_dir = os.path.join(data_dir, 'Test')
        
        self.train_datagen = ImageDataGenerator(rescale=1./255,
                                                validation_split=validation_split,
                                                rotation_range=30.0,
                                                width_shift_range=0.1,
                                                height_shift_range=0.1,
                                                shear_range=0.1,
                                                zoom_range=0.1,
                                                horizontal_flip=True,
                                                brightness_range=[0.8,1.2]
                                               )
        self.test_datagen = ImageDataGenerator(rescale=1./255)
        
    def get_training_data(self, image_size=(224,224), batch_size=32):
        print('Loading Training Data')
        train_generator = self.train_datagen.flow_from_directory(self.train_dir,
                                                                 target_size = image_size,
                                                                 class_mode = 'categorical',
                                                                 batch_size = batch_size,
                                                                 subset = 'training'
                                                                )
        print('Loading Validation Data')
        validation_generator = self.train_datagen.flow_from_directory(self.train_dir,
                                                                      target_size = image_size,
                                                                      class_mode = 'categorical',
                                                                      batch_size = batch_size,
                                                                      shuffle = True,
                                                                      subset = 'validation'
                                                                     )
        return train_generator, validation_generator
    
    def get_testing_data(self, image_size=(224,224), batch_size=32):
        print('Loading Test Data')
        test_generator = self.test_datagen.flow_from_directory(self.test_dir,
                                                               target_size = image_size,
                                                               class_mode = 'categorical',
                                                               batch_size = batch_size,
                                                               shuffle = False
                                                              )
        return test_generator

# %% [markdown]
# ### 2.3 Visualizer

# %%
class Visualizer:
    def __init__(self):
        pass
        
    def pieplot(self, subplot, data, title):
        classes, count = np.unique(data.classes, return_counts=True)
        labels = data.class_indices.keys()
        subplot.pie(count, labels=labels, autopct='%.1f%%')
        subplot.set_title(title)
        
    def show_data_distribution(self, train, validation, test):
        fig, axes = plt.subplots(1,3, figsize=(12, 6))
        
        self.pieplot(axes[0], train, 'Training set')
        self.pieplot(axes[1], validation, 'Validation set')
        self.pieplot(axes[2], test, 'Test set')
        
        plt.show()
        
    def show_confusion_matrix(self, y_true, y_pred, labels):
        cm = confusion_matrix(y_true, y_pred)
        cm_df = pd.DataFrame(cm,
                             index = labels,
                             columns = labels
                            )
        sns.heatmap(cm_df,
                    annot=True,
                    cbar=False,
                    fmt='g',
                    cmap="viridis"
                   )
        plt.title('Confusion Matrix')
        plt.ylabel('Actal Values')
        plt.xlabel('Predicted Values')
        plt.show()
        
    def show_classification_report(self, y_true, y_pred, labels):
        print("Classification Report")
        print("===========================================\n")
        print(classification_report(y_true, y_pred, target_names=labels ))

# %% [markdown]
# ### 2.4 PretrainedModel

# %%
class PretrainedModel:
    def __init__(self, image_size, num_classes, base_model, name=None):
        self.image_size = image_size
        self.input_shape = image_size + (3,)
        self.num_classes = num_classes
        
        # Buat Sequential model + name
        self.model = Sequential(name=name)

        # Base model (misalnya VGG19)
        base_model_instance = base_model(
            weights='imagenet',
            include_top=False,
            input_shape=self.input_shape
        )

        # Freeze base model
        for layer in base_model_instance.layers:
            layer.trainable = False

        # Susun model
        self.model.add(base_model_instance)
        self.model.add(GlobalAveragePooling2D())
        self.model.add(Dense(256, activation='relu', name='new_dense_1'))
        self.model.add(Dropout(0.2))
        self.model.add(Dense(128, activation='relu', name='new_dense_2'))
        self.model.add(Dense(self.num_classes, activation='softmax', name='new_output'))

    def compile(self, optimizer, loss, metrics):
        self.model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    def summary(self):
        self.model.summary()

    def call(self, inputs):
        return self.model(inputs)
        
    def fit(self, *args, **kwargs):
        return self.model.fit(*args, **kwargs)

# %% [markdown]
# ## 3. Initialization

# %%
#tf.keras.utils.set_random_seed = 500

conf = Configuration()
dataloader = DataLoader(conf.data_dir)
visualizer = Visualizer()

# %% [markdown]
# ### 3.1 Hyperparameters

# %%
conf.image_size = (224,224)
conf.learning_rate = 0.001
conf.batch_size = 64
conf.epochs = 30

# %% [markdown]
# ## 4. Loading Dataset

# %% [markdown]
# ### 4.1 Training and Validation Data

# %%
train_gen, val_gen = dataloader.get_training_data(image_size=conf.image_size, batch_size=conf.batch_size)
# Out:
# Loading Training Data
# Found 3992 images belonging to 3 classes.
# Loading Validation Data
# Found 442 images belonging to 3 classes.

# %% [markdown]
# ### 4.2 Testing Data

# %%
test_gen = dataloader.get_testing_data(image_size=conf.image_size, batch_size=conf.batch_size)
# Out:
# Loading Test Data
# Found 180 images belonging to 3 classes.

# %% [markdown]
# ### 4.3 Data Distribution

# %%
visualizer.show_data_distribution(train_gen, val_gen, test_gen)

# %% [markdown]
# ## 5. Building Models

# %% [markdown]
# ### 5.1 Inception V3 Pretrained Model

# %%
inception = PretrainedModel(image_size=conf.image_size,
                                  num_classes=conf.num_classes,
                                  base_model=InceptionV3
                                 )
inception.model.compile(optimizer=conf.optimizer(learning_rate=conf.learning_rate),
                        loss=conf.loss,
                        metrics=conf.metrics
                       )
inception.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)            │ (None, 5, 5, 2048)          │      21,802,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ new_dense_1 (Dense)                  │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ new_dense_2 (Dense)                  │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ new_output (Dense)                   │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,360,611 (85.30 MB)
#  Trainable params: 557,827 (2.13 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %% [markdown]
# ### 5.2 VGG 19 Pretrained Model

# %%
vgg_model = PretrainedModel(
    image_size=conf.image_size,
    num_classes=conf.num_classes,
    base_model=VGG19,
    name='Pretrained_VGG19'
)

vgg_model.compile(
    optimizer=conf.optimizer(learning_rate=conf.learning_rate),
    loss=conf.loss,
    metrics=conf.metrics
)

vgg_model.summary()
# Out:
# Model: "Pretrained_VGG19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg19 (Functional)                   │ (None, 7, 7, 512)           │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ new_dense_1 (Dense)                  │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ new_dense_2 (Dense)                  │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ new_output (Dense)                   │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,188,995 (77.01 MB)
#  Trainable params: 164,611 (643.01 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %% [markdown]
# ### 5.3 Xception Pretrained Model

# %%
xception_model = PretrainedModel(image_size=conf.image_size,
                            num_classes=conf.num_classes,
                            base_model=Xception,
                            name='Pretrained_Xception'
                           )
xception_model.compile(optimizer=conf.optimizer(learning_rate=conf.learning_rate),
                  loss=conf.loss,
                  metrics=conf.metrics
                 )
xception_model.summary()
# Out:
# Model: "Pretrained_Xception"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ xception (Functional)                │ (None, 7, 7, 2048)          │      20,861,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_2           │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ new_dense_1 (Dense)                  │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ new_dense_2 (Dense)                  │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ new_output (Dense)                   │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 21,419,307 (81.71 MB)
#  Trainable params: 557,827 (2.13 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %% [markdown]
# ## 6. Training

# %% [markdown]
# ### 6.1 Inception V3 Pretrained

# %%
inception_history = inception.model.fit(train_gen,
                                        validation_data=val_gen,
                                         epochs=conf.epochs,
                                        verbose=1
                                       )
# Out:
# C:\Users\nofia\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 322s 5s/step - auc: 0.8544 - categorical_accuracy: 0.6796 - loss: 0.7362 - precision: 0.7157 - recall: 0.6242 - val_auc: 0.8551 - val_categorical_accuracy: 0.6652 - val_loss: 0.7076 - val_precision: 0.6870 - val_recall: 0.6109
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 305s 5s/step - auc: 0.9364 - categorical_accuracy: 0.7996 - loss: 0.4812 - precision: 0.8158 - recall: 0.7788 - val_auc: 0.8807 - val_categorical_accuracy: 0.7059 - val_loss: 0.6650 - val_precision: 0.7213 - val_recall: 0.6968
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 285s 5s/step - auc: 0.9477 - categorical_accuracy: 0.8209 - loss: 0.4325 - precision: 0.8307 - recall: 0.8086 - val_auc: 0.8381 - val_categorical_accuracy: 0.6267 - val_loss: 0.8047 - val_precision: 0.6535 - val_recall: 0.5973
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 289s 5s/step - auc: 0.9546 - categorical_accuracy: 0.8342 - loss: 0.4038 - precision: 0.8446 - recall: 0.8249 - val_auc: 0.8740 - val_categorical_accuracy: 0.6855 - val_loss: 0.6725 - val_precision: 0.7079 - val_recall: 0.6471
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 285s 5s/step - auc: 0.9653 - categorical_accuracy: 0.8640 - loss: 0.3506 - precision: 0.8727 - recall: 0.8555 - val_auc: 0.8613 - val_categorical_accuracy: 0.6765 - val_loss: 0.7172 - val_precision: 0.6837 - val_recall: 0.6357
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 287s 5s/step - auc: 0.9643 - categorical_accuracy: 0.8557 - loss: 0.3569 - precision: 0.8648 - recall: 0.8479 - val_auc: 0.8587 - val_categorical_accuracy: 0.6968 - val_loss: 0.7710 - val_precision: 0.7016 - val_recall: 0.6810
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 288s 5s/step - auc: 0.9683 - categorical_accuracy: 0.8642 - loss: 0.3369 - precision: 0.8741 - recall: 0.8560 - val_auc: 0.8754 - val_categorical_accuracy: 0.6855 - val_loss: 0.6841 - val_precision: 0.7052 - val_recall: 0.6765
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 293s 5s/step - auc: 0.9726 - categorical_accuracy: 0.8735 - loss: 0.3131 - precision: 0.8828 - recall: 0.8662 - val_auc: 0.8774 - val_categorical_accuracy: 0.7172 - val_loss: 0.7411 - val_precision: 0.7330 - val_recall: 0.7081
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 284s 5s/step - auc: 0.9708 - categorical_accuracy: 0.8722 - loss: 0.3217 - precision: 0.8774 - recall: 0.8645 - val_auc: 0.8569 - val_categorical_accuracy: 0.6900 - val_loss: 0.7476 - val_precision: 0.6954 - val_recall: 0.6561
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 291s 5s/step - auc: 0.9775 - categorical_accuracy: 0.8848 - loss: 0.2824 - precision: 0.8921 - recall: 0.8778 - val_auc: 0.8921 - val_categorical_accuracy: 0.7376 - val_loss: 0.6966 - val_precision: 0.7391 - val_recall: 0.7308
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 291s 5s/step - auc: 0.9748 - categorical_accuracy: 0.8865 - loss: 0.2968 - precision: 0.8939 - recall: 0.8818 - val_auc: 0.8696 - val_categorical_accuracy: 0.6923 - val_loss: 0.7493 - val_precision: 0.7098 - val_recall: 0.6697
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 282s 4s/step - auc: 0.9797 - categorical_accuracy: 0.8963 - loss: 0.2663 - precision: 0.9019 - recall: 0.8908 - val_auc: 0.8818 - val_categorical_accuracy: 0.7398 - val_loss: 0.7197 - val_precision: 0.7476 - val_recall: 0.7172
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 283s 4s/step - auc: 0.9773 - categorical_accuracy: 0.8900 - loss: 0.2808 - precision: 0.8981 - recall: 0.8850 - val_auc: 0.8788 - val_categorical_accuracy: 0.6878 - val_loss: 0.7175 - val_precision: 0.7024 - val_recall: 0.6674
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 287s 5s/step - auc: 0.9804 - categorical_accuracy: 0.8958 - loss: 0.2628 - precision: 0.9018 - recall: 0.8905 - val_auc: 0.8827 - val_categorical_accuracy: 0.7104 - val_loss: 0.7009 - val_precision: 0.7187 - val_recall: 0.6878
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 284s 4s/step - auc: 0.9808 - categorical_accuracy: 0.8998 - loss: 0.2586 - precision: 0.9057 - recall: 0.8928 - val_auc: 0.8593 - val_categorical_accuracy: 0.6742 - val_loss: 0.8637 - val_precision: 0.6874 - val_recall: 0.6516
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 250s 4s/step - auc: 0.9833 - categorical_accuracy: 0.9048 - loss: 0.2409 - precision: 0.9090 - recall: 0.8983 - val_auc: 0.8828 - val_categorical_accuracy: 0.7127 - val_loss: 0.7842 - val_precision: 0.7169 - val_recall: 0.7104
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 283s 4s/step - auc: 0.9847 - categorical_accuracy: 0.9053 - loss: 0.2301 - precision: 0.9106 - recall: 0.9003 - val_auc: 0.8944 - val_categorical_accuracy: 0.7511 - val_loss: 0.6783 - val_precision: 0.7604 - val_recall: 0.7466
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 298s 5s/step - auc: 0.9806 - categorical_accuracy: 0.8923 - loss: 0.2594 - precision: 0.8977 - recall: 0.8883 - val_auc: 0.8675 - val_categorical_accuracy: 0.7059 - val_loss: 0.7982 - val_precision: 0.7139 - val_recall: 0.6833
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 296s 5s/step - auc: 0.9826 - categorical_accuracy: 0.9046 - loss: 0.2428 - precision: 0.9096 - recall: 0.9003 - val_auc: 0.8597 - val_categorical_accuracy: 0.6855 - val_loss: 0.8533 - val_precision: 0.6967 - val_recall: 0.6652
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 289s 5s/step - auc: 0.9854 - categorical_accuracy: 0.9116 - loss: 0.2242 - precision: 0.9150 - recall: 0.9063 - val_auc: 0.8885 - val_categorical_accuracy: 0.7217 - val_loss: 0.7133 - val_precision: 0.7273 - val_recall: 0.7059
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 278s 4s/step - auc: 0.9839 - categorical_accuracy: 0.9078 - loss: 0.2352 - precision: 0.9115 - recall: 0.9026 - val_auc: 0.8402 - val_categorical_accuracy: 0.6742 - val_loss: 0.8989 - val_precision: 0.6835 - val_recall: 0.6742
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 320s 5s/step - auc: 0.9863 - categorical_accuracy: 0.9153 - loss: 0.2164 - precision: 0.9201 - recall: 0.9111 - val_auc: 0.8632 - val_categorical_accuracy: 0.7059 - val_loss: 0.8695 - val_precision: 0.7089 - val_recall: 0.6833
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 278s 4s/step - auc: 0.9853 - categorical_accuracy: 0.9131 - loss: 0.2228 - precision: 0.9167 - recall: 0.9098 - val_auc: 0.8732 - val_categorical_accuracy: 0.6833 - val_loss: 0.8151 - val_precision: 0.6874 - val_recall: 0.6765
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 277s 4s/step - auc: 0.9866 - categorical_accuracy: 0.9163 - loss: 0.2121 - precision: 0.9195 - recall: 0.9126 - val_auc: 0.8572 - val_categorical_accuracy: 0.6697 - val_loss: 0.8490 - val_precision: 0.6817 - val_recall: 0.6493
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 289s 5s/step - auc: 0.9860 - categorical_accuracy: 0.9171 - loss: 0.2180 - precision: 0.9197 - recall: 0.9121 - val_auc: 0.8229 - val_categorical_accuracy: 0.6448 - val_loss: 1.0880 - val_precision: 0.6589 - val_recall: 0.6425
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 298s 5s/step - auc: 0.9874 - categorical_accuracy: 0.9141 - loss: 0.2074 - precision: 0.9188 - recall: 0.9098 - val_auc: 0.8360 - val_categorical_accuracy: 0.6810 - val_loss: 1.0142 - val_precision: 0.6889 - val_recall: 0.6765
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 297s 5s/step - auc: 0.9856 - categorical_accuracy: 0.9151 - loss: 0.2207 - precision: 0.9186 - recall: 0.9126 - val_auc: 0.8465 - val_categorical_accuracy: 0.6787 - val_loss: 0.9200 - val_precision: 0.6868 - val_recall: 0.6697
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 299s 5s/step - auc: 0.9829 - categorical_accuracy: 0.9073 - loss: 0.2399 - precision: 0.9105 - recall: 0.9023 - val_auc: 0.8500 - val_categorical_accuracy: 0.6833 - val_loss: 0.8540 - val_precision: 0.6900 - val_recall: 0.6697
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 304s 5s/step - auc: 0.9862 - categorical_accuracy: 0.9118 - loss: 0.2173 - precision: 0.9165 - recall: 0.9078 - val_auc: 0.8568 - val_categorical_accuracy: 0.6742 - val_loss: 0.9316 - val_precision: 0.6910 - val_recall: 0.6629
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 291s 5s/step - auc: 0.9871 - categorical_accuracy: 0.9231 - loss: 0.2085 - precision: 0.9274 - recall: 0.9178 - val_auc: 0.8520 - val_categorical_accuracy: 0.7081 - val_loss: 0.9740 - val_precision: 0.7140 - val_recall: 0.7059

# %% [markdown]
# ### 6.2 VGG 19 Pretrained

# %%
train_gen.reset()
val_gen.reset()

# %%
vgg_history = vgg_model.model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=conf.epochs,
    verbose=1
)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1506s 24s/step - auc: 0.7227 - categorical_accuracy: 0.5268 - loss: 0.9575 - precision: 0.6161 - recall: 0.3204 - val_auc: 0.7121 - val_categorical_accuracy: 0.4615 - val_loss: 0.9374 - val_precision: 0.4750 - val_recall: 0.3869
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1460s 23s/step - auc: 0.8249 - categorical_accuracy: 0.6293 - loss: 0.7828 - precision: 0.6965 - recall: 0.5158 - val_auc: 0.7777 - val_categorical_accuracy: 0.5407 - val_loss: 0.8646 - val_precision: 0.5474 - val_recall: 0.5226
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1388s 22s/step - auc: 0.8746 - categorical_accuracy: 0.6986 - loss: 0.6733 - precision: 0.7421 - recall: 0.6330 - val_auc: 0.8079 - val_categorical_accuracy: 0.5928 - val_loss: 0.8051 - val_precision: 0.6233 - val_recall: 0.5090
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10381s 167s/step - auc: 0.8980 - categorical_accuracy: 0.7375 - loss: 0.6116 - precision: 0.7685 - recall: 0.6869 - val_auc: 0.7949 - val_categorical_accuracy: 0.5656 - val_loss: 0.8572 - val_precision: 0.6041 - val_recall: 0.5385
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1368s 22s/step - auc: 0.9219 - categorical_accuracy: 0.7788 - loss: 0.5357 - precision: 0.8041 - recall: 0.7405 - val_auc: 0.8129 - val_categorical_accuracy: 0.6063 - val_loss: 0.8336 - val_precision: 0.6396 - val_recall: 0.5701
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1402s 22s/step - auc: 0.9240 - categorical_accuracy: 0.7806 - loss: 0.5275 - precision: 0.8040 - recall: 0.7480 - val_auc: 0.8053 - val_categorical_accuracy: 0.6041 - val_loss: 0.8548 - val_precision: 0.6161 - val_recall: 0.5701
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1414s 22s/step - auc: 0.9308 - categorical_accuracy: 0.7991 - loss: 0.5061 - precision: 0.8174 - recall: 0.7683 - val_auc: 0.8025 - val_categorical_accuracy: 0.6086 - val_loss: 0.9267 - val_precision: 0.6232 - val_recall: 0.5837
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1469s 23s/step - auc: 0.9369 - categorical_accuracy: 0.8021 - loss: 0.4798 - precision: 0.8212 - recall: 0.7791 - val_auc: 0.7776 - val_categorical_accuracy: 0.5679 - val_loss: 0.9673 - val_precision: 0.5739 - val_recall: 0.5181
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1407s 22s/step - auc: 0.9373 - categorical_accuracy: 0.8004 - loss: 0.4778 - precision: 0.8227 - recall: 0.7751 - val_auc: 0.8275 - val_categorical_accuracy: 0.6312 - val_loss: 0.8481 - val_precision: 0.6342 - val_recall: 0.6041
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5148s 83s/step - auc: 0.9441 - categorical_accuracy: 0.8176 - loss: 0.4520 - precision: 0.8321 - recall: 0.7921 - val_auc: 0.8053 - val_categorical_accuracy: 0.6041 - val_loss: 0.9245 - val_precision: 0.6171 - val_recall: 0.5724
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22426s 361s/step - auc: 0.9457 - categorical_accuracy: 0.8229 - loss: 0.4419 - precision: 0.8355 - recall: 0.8039 - val_auc: 0.7696 - val_categorical_accuracy: 0.5475 - val_loss: 1.0223 - val_precision: 0.5537 - val_recall: 0.5249
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1383s 22s/step - auc: 0.9486 - categorical_accuracy: 0.8219 - loss: 0.4289 - precision: 0.8377 - recall: 0.8066 - val_auc: 0.8072 - val_categorical_accuracy: 0.5928 - val_loss: 0.8977 - val_precision: 0.6143 - val_recall: 0.5656
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2335s 37s/step - auc: 0.9482 - categorical_accuracy: 0.8234 - loss: 0.4332 - precision: 0.8361 - recall: 0.8061 - val_auc: 0.7997 - val_categorical_accuracy: 0.6244 - val_loss: 0.9693 - val_precision: 0.6256 - val_recall: 0.6086
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1446s 23s/step - auc: 0.9558 - categorical_accuracy: 0.8387 - loss: 0.4019 - precision: 0.8517 - recall: 0.8214 - val_auc: 0.7999 - val_categorical_accuracy: 0.6063 - val_loss: 0.9716 - val_precision: 0.6158 - val_recall: 0.5837
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1393s 22s/step - auc: 0.9494 - categorical_accuracy: 0.8209 - loss: 0.4273 - precision: 0.8357 - recall: 0.8076 - val_auc: 0.8201 - val_categorical_accuracy: 0.6222 - val_loss: 0.8817 - val_precision: 0.6241 - val_recall: 0.5860
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1403s 22s/step - auc: 0.9525 - categorical_accuracy: 0.8294 - loss: 0.4130 - precision: 0.8428 - recall: 0.8124 - val_auc: 0.8046 - val_categorical_accuracy: 0.6222 - val_loss: 0.9006 - val_precision: 0.6401 - val_recall: 0.5995
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 43629s 703s/step - auc: 0.9548 - categorical_accuracy: 0.8292 - loss: 0.4034 - precision: 0.8438 - recall: 0.8134 - val_auc: 0.8050 - val_categorical_accuracy: 0.6063 - val_loss: 0.9067 - val_precision: 0.6202 - val_recall: 0.5837
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1448s 23s/step - auc: 0.9523 - categorical_accuracy: 0.8317 - loss: 0.4142 - precision: 0.8444 - recall: 0.8196 - val_auc: 0.8090 - val_categorical_accuracy: 0.6018 - val_loss: 0.8911 - val_precision: 0.6099 - val_recall: 0.5588
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1464s 23s/step - auc: 0.9590 - categorical_accuracy: 0.8444 - loss: 0.3860 - precision: 0.8571 - recall: 0.8262 - val_auc: 0.8023 - val_categorical_accuracy: 0.6018 - val_loss: 0.9714 - val_precision: 0.6085 - val_recall: 0.5837
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1503s 24s/step - auc: 0.9601 - categorical_accuracy: 0.8469 - loss: 0.3792 - precision: 0.8578 - recall: 0.8339 - val_auc: 0.7843 - val_categorical_accuracy: 0.5679 - val_loss: 0.9849 - val_precision: 0.5770 - val_recall: 0.5339
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1445s 23s/step - auc: 0.9613 - categorical_accuracy: 0.8487 - loss: 0.3745 - precision: 0.8614 - recall: 0.8342 - val_auc: 0.7409 - val_categorical_accuracy: 0.5339 - val_loss: 1.2811 - val_precision: 0.5379 - val_recall: 0.5136
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1464s 23s/step - auc: 0.9636 - categorical_accuracy: 0.8547 - loss: 0.3618 - precision: 0.8675 - recall: 0.8412 - val_auc: 0.7926 - val_categorical_accuracy: 0.5905 - val_loss: 1.0509 - val_precision: 0.5935 - val_recall: 0.5747
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1498s 24s/step - auc: 0.9650 - categorical_accuracy: 0.8590 - loss: 0.3547 - precision: 0.8697 - recall: 0.8474 - val_auc: 0.7879 - val_categorical_accuracy: 0.5792 - val_loss: 1.0268 - val_precision: 0.5813 - val_recall: 0.5498
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2161s 34s/step - auc: 0.9652 - categorical_accuracy: 0.8597 - loss: 0.3541 - precision: 0.8726 - recall: 0.8477 - val_auc: 0.7756 - val_categorical_accuracy: 0.5814 - val_loss: 1.1036 - val_precision: 0.5860 - val_recall: 0.5475
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1504s 24s/step - auc: 0.9627 - categorical_accuracy: 0.8555 - loss: 0.3662 - precision: 0.8673 - recall: 0.8432 - val_auc: 0.7737 - val_categorical_accuracy: 0.5679 - val_loss: 1.1202 - val_precision: 0.5755 - val_recall: 0.5520
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1486s 24s/step - auc: 0.9637 - categorical_accuracy: 0.8512 - loss: 0.3607 - precision: 0.8622 - recall: 0.8402 - val_auc: 0.8165 - val_categorical_accuracy: 0.5995 - val_loss: 0.8999 - val_precision: 0.6214 - val_recall: 0.5792
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1513s 24s/step - auc: 0.9626 - categorical_accuracy: 0.8560 - loss: 0.3667 - precision: 0.8658 - recall: 0.8422 - val_auc: 0.7542 - val_categorical_accuracy: 0.5339 - val_loss: 1.1466 - val_precision: 0.5510 - val_recall: 0.5136
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1419s 23s/step - auc: 0.9687 - categorical_accuracy: 0.8605 - loss: 0.3356 - precision: 0.8727 - recall: 0.8464 - val_auc: 0.7469 - val_categorical_accuracy: 0.5385 - val_loss: 1.2921 - val_precision: 0.5377 - val_recall: 0.5158
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1366s 22s/step - auc: 0.9678 - categorical_accuracy: 0.8595 - loss: 0.3396 - precision: 0.8712 - recall: 0.8474 - val_auc: 0.8165 - val_categorical_accuracy: 0.6244 - val_loss: 0.9451 - val_precision: 0.6381 - val_recall: 0.6063
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1403s 22s/step - auc: 0.9684 - categorical_accuracy: 0.8590 - loss: 0.3360 - precision: 0.8721 - recall: 0.8474 - val_auc: 0.7720 - val_categorical_accuracy: 0.5633 - val_loss: 1.0938 - val_precision: 0.5667 - val_recall: 0.5385

# %% [markdown]
# ### 6.3 Xception Pretrained

# %%
train_gen.reset()
val_gen.reset()

# %%
xception_history = xception_model.fit(train_gen,
                            validation_data=val_gen,
                            epochs=conf.epochs,
                            verbose=1
                           )
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 494s 8s/step - auc: 0.9273 - categorical_accuracy: 0.7841 - loss: 0.5182 - precision: 0.8177 - recall: 0.7492 - val_auc: 0.8825 - val_categorical_accuracy: 0.7376 - val_loss: 0.6703 - val_precision: 0.7379 - val_recall: 0.7262
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 467s 7s/step - auc: 0.9632 - categorical_accuracy: 0.8630 - loss: 0.3597 - precision: 0.8701 - recall: 0.8537 - val_auc: 0.9069 - val_categorical_accuracy: 0.7511 - val_loss: 0.5772 - val_precision: 0.7612 - val_recall: 0.7285
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 475s 8s/step - auc: 0.9729 - categorical_accuracy: 0.8780 - loss: 0.3089 - precision: 0.8847 - recall: 0.8687 - val_auc: 0.9023 - val_categorical_accuracy: 0.7511 - val_loss: 0.6240 - val_precision: 0.7622 - val_recall: 0.7398
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 504s 8s/step - auc: 0.9778 - categorical_accuracy: 0.8955 - loss: 0.2780 - precision: 0.9003 - recall: 0.8890 - val_auc: 0.8883 - val_categorical_accuracy: 0.7104 - val_loss: 0.6548 - val_precision: 0.7275 - val_recall: 0.6946
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 474s 8s/step - auc: 0.9794 - categorical_accuracy: 0.8965 - loss: 0.2691 - precision: 0.9026 - recall: 0.8893 - val_auc: 0.8922 - val_categorical_accuracy: 0.7376 - val_loss: 0.6370 - val_precision: 0.7436 - val_recall: 0.7217
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - auc: 0.9836 - categorical_accuracy: 0.9041 - loss: 0.2375 - precision: 0.9085 - recall: 0.9001 - val_auc: 0.8638 - val_categorical_accuracy: 0.7172 - val_loss: 0.7943 - val_precision: 0.7249 - val_recall: 0.7036
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 490s 8s/step - auc: 0.9854 - categorical_accuracy: 0.9093 - loss: 0.2250 - precision: 0.9129 - recall: 0.9058 - val_auc: 0.8849 - val_categorical_accuracy: 0.7217 - val_loss: 0.6890 - val_precision: 0.7229 - val_recall: 0.7081
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 477s 8s/step - auc: 0.9839 - categorical_accuracy: 0.9111 - loss: 0.2340 - precision: 0.9144 - recall: 0.9071 - val_auc: 0.7956 - val_categorical_accuracy: 0.6176 - val_loss: 1.1663 - val_precision: 0.6273 - val_recall: 0.6131
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 466s 7s/step - auc: 0.9874 - categorical_accuracy: 0.9188 - loss: 0.2090 - precision: 0.9239 - recall: 0.9153 - val_auc: 0.8886 - val_categorical_accuracy: 0.7443 - val_loss: 0.7262 - val_precision: 0.7477 - val_recall: 0.7376
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 447s 7s/step - auc: 0.9860 - categorical_accuracy: 0.9143 - loss: 0.2216 - precision: 0.9168 - recall: 0.9113 - val_auc: 0.8792 - val_categorical_accuracy: 0.7149 - val_loss: 0.7693 - val_precision: 0.7153 - val_recall: 0.6991
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 440s 7s/step - auc: 0.9898 - categorical_accuracy: 0.9291 - loss: 0.1833 - precision: 0.9326 - recall: 0.9256 - val_auc: 0.8863 - val_categorical_accuracy: 0.7036 - val_loss: 0.7424 - val_precision: 0.7179 - val_recall: 0.6968
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 473s 8s/step - auc: 0.9907 - categorical_accuracy: 0.9361 - loss: 0.1740 - precision: 0.9379 - recall: 0.9339 - val_auc: 0.8822 - val_categorical_accuracy: 0.7149 - val_loss: 0.7688 - val_precision: 0.7327 - val_recall: 0.6946
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 480s 8s/step - auc: 0.9899 - categorical_accuracy: 0.9341 - loss: 0.1828 - precision: 0.9358 - recall: 0.9316 - val_auc: 0.8622 - val_categorical_accuracy: 0.7127 - val_loss: 0.9212 - val_precision: 0.7172 - val_recall: 0.7059
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 445s 7s/step - auc: 0.9897 - categorical_accuracy: 0.9306 - loss: 0.1860 - precision: 0.9324 - recall: 0.9291 - val_auc: 0.9009 - val_categorical_accuracy: 0.7511 - val_loss: 0.6842 - val_precision: 0.7558 - val_recall: 0.7421
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 441s 7s/step - auc: 0.9921 - categorical_accuracy: 0.9361 - loss: 0.1657 - precision: 0.9390 - recall: 0.9334 - val_auc: 0.8792 - val_categorical_accuracy: 0.7059 - val_loss: 0.8272 - val_precision: 0.7120 - val_recall: 0.6991
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 441s 7s/step - auc: 0.9912 - categorical_accuracy: 0.9366 - loss: 0.1669 - precision: 0.9403 - recall: 0.9346 - val_auc: 0.8905 - val_categorical_accuracy: 0.7195 - val_loss: 0.8143 - val_precision: 0.7336 - val_recall: 0.7104
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 446s 7s/step - auc: 0.9935 - categorical_accuracy: 0.9409 - loss: 0.1464 - precision: 0.9425 - recall: 0.9399 - val_auc: 0.9089 - val_categorical_accuracy: 0.7760 - val_loss: 0.7240 - val_precision: 0.7894 - val_recall: 0.7715
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 490s 8s/step - auc: 0.9930 - categorical_accuracy: 0.9404 - loss: 0.1529 - precision: 0.9431 - recall: 0.9381 - val_auc: 0.8472 - val_categorical_accuracy: 0.6855 - val_loss: 1.0173 - val_precision: 0.6930 - val_recall: 0.6742
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 445s 7s/step - auc: 0.9939 - categorical_accuracy: 0.9486 - loss: 0.1407 - precision: 0.9507 - recall: 0.9471 - val_auc: 0.8940 - val_categorical_accuracy: 0.7195 - val_loss: 0.8303 - val_precision: 0.7208 - val_recall: 0.7127
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3893s 63s/step - auc: 0.9936 - categorical_accuracy: 0.9441 - loss: 0.1445 - precision: 0.9450 - recall: 0.9424 - val_auc: 0.8553 - val_categorical_accuracy: 0.6900 - val_loss: 1.0240 - val_precision: 0.6925 - val_recall: 0.6878
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 393s 6s/step - auc: 0.9930 - categorical_accuracy: 0.9439 - loss: 0.1512 - precision: 0.9459 - recall: 0.9421 - val_auc: 0.8712 - val_categorical_accuracy: 0.6855 - val_loss: 0.9807 - val_precision: 0.6897 - val_recall: 0.6787
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3620s 58s/step - auc: 0.9922 - categorical_accuracy: 0.9411 - loss: 0.1570 - precision: 0.9429 - recall: 0.9386 - val_auc: 0.8839 - val_categorical_accuracy: 0.7330 - val_loss: 0.9210 - val_precision: 0.7419 - val_recall: 0.7285
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 346s 5s/step - auc: 0.9930 - categorical_accuracy: 0.9431 - loss: 0.1486 - precision: 0.9452 - recall: 0.9416 - val_auc: 0.8870 - val_categorical_accuracy: 0.7466 - val_loss: 0.8880 - val_precision: 0.7540 - val_recall: 0.7421
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1025s 16s/step - auc: 0.9937 - categorical_accuracy: 0.9461 - loss: 0.1411 - precision: 0.9480 - recall: 0.9444 - val_auc: 0.8580 - val_categorical_accuracy: 0.6991 - val_loss: 1.1010 - val_precision: 0.7034 - val_recall: 0.6923
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 413s 7s/step - auc: 0.9944 - categorical_accuracy: 0.9471 - loss: 0.1339 - precision: 0.9499 - recall: 0.9461 - val_auc: 0.8789 - val_categorical_accuracy: 0.7014 - val_loss: 0.9624 - val_precision: 0.7055 - val_recall: 0.6991
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 553s 9s/step - auc: 0.9949 - categorical_accuracy: 0.9512 - loss: 0.1291 - precision: 0.9535 - recall: 0.9502 - val_auc: 0.8886 - val_categorical_accuracy: 0.7421 - val_loss: 0.8560 - val_precision: 0.7506 - val_recall: 0.7353
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 438s 7s/step - auc: 0.9952 - categorical_accuracy: 0.9517 - loss: 0.1246 - precision: 0.9532 - recall: 0.9499 - val_auc: 0.8808 - val_categorical_accuracy: 0.7353 - val_loss: 0.9271 - val_precision: 0.7391 - val_recall: 0.7308
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 445s 7s/step - auc: 0.9948 - categorical_accuracy: 0.9484 - loss: 0.1302 - precision: 0.9493 - recall: 0.9469 - val_auc: 0.8814 - val_categorical_accuracy: 0.7398 - val_loss: 0.8962 - val_precision: 0.7414 - val_recall: 0.7330
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 440s 7s/step - auc: 0.9946 - categorical_accuracy: 0.9486 - loss: 0.1335 - precision: 0.9493 - recall: 0.9471 - val_auc: 0.8814 - val_categorical_accuracy: 0.7285 - val_loss: 0.9341 - val_precision: 0.7318 - val_recall: 0.7285
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 443s 7s/step - auc: 0.9957 - categorical_accuracy: 0.9539 - loss: 0.1124 - precision: 0.9546 - recall: 0.9527 - val_auc: 0.8448 - val_categorical_accuracy: 0.7036 - val_loss: 1.2930 - val_precision: 0.7023 - val_recall: 0.6991

# %% [markdown]
# ## 7. Evaluation on Test Data

# %% [markdown]
# ### 7.1 Inception V3 Pretrained

# %%
y_pred_inception = inception.model.predict(test_gen)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step

# %%
visualizer.show_confusion_matrix(test_gen.labels, y_pred_inception.argmax(axis=1), labels=test_gen.class_indices.keys())

# %%
visualizer.show_classification_report(test_gen.labels, y_pred_inception.argmax(axis=1), test_gen.class_indices.keys())
# Out:
# Classification Report
# ===========================================
#
#               precision    recall  f1-score   support
#
#     Overripe       0.98      0.97      0.97        60
#         Ripe       0.83      0.97      0.89        60
#       Unripe       0.98      0.83      0.90        60
#
#     accuracy                           0.92       180
#    macro avg       0.93      0.92      0.92       180
# weighted avg       0.93      0.92      0.92       180

# %%
print(inception_model.metrics_names)
# Out:
# ['loss', 'compile_metrics']

# %%
print(conf.metrics)
# Out:
# ['categorical_accuracy', 'precision', 'recall', 'auc']

# %%
test_gen.reset()
results = inception_model.evaluate(
    test_gen,
    verbose=1,
    return_dict=True
)

print("Akurasi Inception:",
      results['categorical_accuracy'] * 100, "%")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - auc: 0.9888 - categorical_accuracy: 0.9222 - loss: 0.1911 - precision: 0.9222 - recall: 0.9222
# Akurasi Inception: 92.22221970558167 %

# %% [markdown]
# ### 7.2 VGG 19 Pretrained

# %%
# Ambil model keras dari wrapper
vgg_keras = vgg_model.model

# Reset generator biar urutan label aman
test_gen.reset()

# Prediksi
y_pred_vgg = vgg_keras.predict(test_gen)
y_pred_vgg_cls = y_pred_vgg.argmax(axis=1)

# Evaluasi
visualizer.show_confusion_matrix(
    test_gen.labels,
    y_pred_vgg_cls,
    labels=list(test_gen.class_indices.keys())
)

visualizer.show_classification_report(
    test_gen.labels,
    y_pred_vgg_cls,
    list(test_gen.class_indices.keys())
)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 48s 15s/step
# Classification Report
# ===========================================
#
#               precision    recall  f1-score   support
#
#     Overripe       0.94      0.80      0.86        60
#         Ripe       0.69      0.92      0.79        60
#       Unripe       0.96      0.78      0.86        60
#
#     accuracy                           0.83       180
#    macro avg       0.86      0.83      0.84       180
# weighted avg       0.86      0.83      0.84       180

# %%
# Ekstrak keras model dari wrapper
vgg_keras = vgg_model.model

test_gen.reset()

results_vgg = vgg_keras.evaluate(
    test_gen,
    verbose=1,
    return_dict=True
)

print(f"Akurasi VGG19 : {results_vgg['categorical_accuracy'] * 100:.2f}%")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 11s/step - auc: 0.9601 - categorical_accuracy: 0.8333 - loss: 0.3721 - precision: 0.8315 - recall: 0.8222
# Akurasi VGG19 : 83.33%

# %% [markdown]
# ### 7.3 Xception Pretrained

# %%
# Ambil model keras dari wrapper
xception_keras = xception_model.model

# Reset generator agar sinkron
test_gen.reset()

# Prediksi
y_pred_xception = xception_keras.predict(test_gen)
y_pred_xception_cls = y_pred_xception.argmax(axis=1)

# Evaluasi
visualizer.show_confusion_matrix(
    test_gen.labels,
    y_pred_xception_cls,
    labels=list(test_gen.class_indices.keys())
)

visualizer.show_classification_report(
    test_gen.labels,
    y_pred_xception_cls,
    list(test_gen.class_indices.keys())
)
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F531DB1E40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 4s 5s/step WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F531DB1E40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step
# Classification Report
# ===========================================
#
#               precision    recall  f1-score   support
#
#     Overripe       0.92      0.97      0.94        60
#         Ripe       0.87      0.88      0.88        60
#       Unripe       0.96      0.90      0.93        60
#
#     accuracy                           0.92       180
#    macro avg       0.92      0.92      0.92       180
# weighted avg       0.92      0.92      0.92       180

# %%
# Ambil keras model dari wrapper
xception_keras = xception_model.model

test_gen.reset()

results_xception = xception_keras.evaluate(
    test_gen,
    verbose=1,
    return_dict=True
)

print(f"Akurasi Xception : {results_xception['categorical_accuracy'] * 100:.2f}%")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - auc: 0.9829 - categorical_accuracy: 0.9167 - loss: 0.2882 - precision: 0.9162 - recall: 0.9111
# Akurasi Xception : 91.67%

# %%
# Ambil model keras dari wrapper
inception_model = inception.model

# %%
inception_model.save(
    r'C:/Users/nofia/pcd/Deteksi buah/inception_224_0.0001_128_30.keras')

vgg_model.model.save(
    r'C:/Users/nofia/pcd/Deteksi buah/vgg_224_0.0001_128_30.keras')

xception_model.model.save(
    r'C:/Users/nofia/pcd/Deteksi buah/xception_224_0.0001_128_30.keras')

# %%
inception.model.save('inception_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
